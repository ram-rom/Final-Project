# %%
import pandas as pd 
import numpy as np
import scipy as stats
import seaborn as sns
from matplotlib import pyplot as plt

# %%
dataset1 = pd.read_csv('/analysis/perceptron_ght_2bit/miss_rate.csv')
dataset2= pd.read_csv('/analysis/perceptron_ght_4bit/miss_rate.csv')
dataset3= pd.read_csv('/analysis/perceptron_ght_8bit/miss_rate.csv')
dataset4 = pd.read_csv('/analysis/perceptron_ght_16bit/miss_rate.csv')
dataset5 = pd.read_csv('/analysis/perceptron_ght_31bit/miss_rate.csv')

# %%
dataset6 = pd.read_csv('C:/Users/kusha/Desktop/sem2/ML/analysis/gshare_ght_2bit/miss_rate.csv')
dataset7= pd.read_csv('C:/Users/kusha/Desktop/sem2/ML/analysis/gshare_ght_4bit/miss_rate.csv')
dataset8= pd.read_csv('C:/Users/kusha/Desktop/sem2/ML/analysis/gshare_ght_8bit/miss_rate.csv')
dataset9 = pd.read_csv('C:/Users/kusha/Desktop/sem2/ML/analysis/gshare_ght_16bit/miss_rate.csv')
dataset10 = pd.read_csv('C:/Users/kusha/Desktop/sem2/ML/analysis/gshare_ght_31bit/miss_rate.csv')

# %%
print(dataset1)
print(dataset2)
print(dataset3)
print(dataset4)
print(dataset5)
# Out:
#     predictor  anagram.alpha  cc1.alpha  compress95.alpha  go.alpha
# 0  perceptron         0.2399    0.20131           0.48281   0.23631
#     predictor  anagram.alpha  cc1.alpha  compress95.alpha  go.alpha
# 0  perceptron         0.2399    0.20131           0.48281   0.23631
#     predictor  anagram.alpha  cc1.alpha  compress95.alpha  go.alpha
# 0  perceptron         0.2399    0.20131           0.48281   0.23631
#     predictor  anagram.alpha  cc1.alpha  compress95.alpha  go.alpha
# 0  perceptron         0.2399    0.20131           0.48281   0.23631
#     predictor  anagram.alpha  cc1.alpha  compress95.alpha  go.alpha
# 0  perceptron         0.2399    0.20131           0.48281   0.23631

# %%
print(dataset6)
print(dataset7)
print(dataset8)
print(dataset9)
print(dataset10)
# Out:
#   predictor  anagram.alpha  cc1.alpha  compress95.alpha  go.alpha
# 0    gshare        0.22915    0.20228           0.02042   0.23983
#   predictor  anagram.alpha  cc1.alpha  compress95.alpha  go.alpha
# 0    gshare        0.06885    0.18046           0.02203   0.21977
#   predictor  anagram.alpha  cc1.alpha  compress95.alpha  go.alpha
# 0    gshare        0.03532    0.11891           0.02076   0.17531
#   predictor  anagram.alpha  cc1.alpha  compress95.alpha  go.alpha
# 0    gshare        0.03462    0.07132           0.02094   0.14484
#   predictor  anagram.alpha  cc1.alpha  compress95.alpha  go.alpha
# 0    gshare        0.03462    0.07114           0.02094   0.14484

# %%
ds1 = dataset1.drop(['predictor'] , axis=1)
ds2 = dataset2.drop(['predictor'] , axis=1)
ds3 = dataset3.drop(['predictor'] , axis=1)
ds4 = dataset4.drop(['predictor'] , axis=1)
ds5 = dataset5.drop(['predictor'] , axis=1)
ds6 = dataset6.drop(['predictor'] , axis=1)
ds7 = dataset7.drop(['predictor'] , axis=1)
ds8 = dataset8.drop(['predictor'] , axis=1)
ds9 = dataset9.drop(['predictor'] , axis=1)
ds10 = dataset10.drop(['predictor'] , axis=1)

# %%
objects = ds1.columns
y_pos = np.arange(len(objects))
w=0.35
p1 = ds1.values[0]
p2 = ds2.values[0]
p3 = ds3.values[0]
p4 = ds4.values[0]
p5 = ds5.values[0]
p6 = ds6.values[0]
p7 = ds7.values[0]
p8 = ds8.values[0]
p9 = ds9.values[0]
p10 = ds10.values[0]


plt.plot(p1, 'ro-' ,linewidth=1 , color = 'red' , label =' perceptron 2 bit')

plt.plot(p6, 'ro-' ,linewidth=1 , color = 'blue' , label = 'gshare 2 bits')

plt.xticks(y_pos,objects)
#plt.xlabel('Benchmarks')
plt.ylabel('Misses')
plt.title("performance metrics of perceptron and gshare  at 2 bits - misses ")
plt.legend(loc='best')
plt.show()

# %%
plt.plot(p2, 'ro-' ,linewidth=1 , color = 'red' , label =' perceptron 4 bit')

plt.plot(p7, 'ro-' ,linewidth=1 , color = 'blue' , label = 'gshare 4 bits')

plt.xticks(y_pos,objects)
#plt.xlabel('Benchmarks')
plt.ylabel('Misses')
plt.title("performance metrics of perceptron and gshare  at 4 bits - misses ")
plt.legend(loc='best')
plt.show()

# %%
plt.plot(p3, 'ro-' ,linewidth=1 , color = 'red' , label =' perceptron 8 bit')

plt.plot(p8, 'ro-' ,linewidth=1 , color = 'blue' , label = 'gshare 8 bits')

plt.xticks(y_pos,objects)
#plt.xlabel('Benchmarks')
plt.ylabel('Misses')
plt.title("performance metrics of perceptron and gshare  at 8 bits - misses ")
plt.legend(loc='best')
plt.show()

# %%
plt.plot(p4, 'ro-' ,linewidth=1 , color = 'red' , label =' perceptron 16 bit')

plt.plot(p9, 'ro-' ,linewidth=1 , color = 'blue' , label = 'gshare 16 bits')

plt.xticks(y_pos,objects)
#plt.xlabel('Benchmarks')
plt.ylabel('Misses')
plt.title("performance metrics of perceptron and gshare  at 16 bits - misses ")
plt.legend(loc='best')
plt.show()

# %%
plt.plot(p5, 'ro-' ,linewidth=1 , color = 'red' , label =' perceptron 31 bit')

plt.plot(p10, 'ro-' ,linewidth=1 , color = 'blue' , label = 'gshare 31 bits')

plt.xticks(y_pos,objects)
#plt.xlabel('Benchmarks')
plt.ylabel('Misses')
plt.title("performance metrics of perceptron and gshare  at 31 bits - misses ")
plt.legend(loc='best')
plt.show()
